# %%
# NB1: SYMPTOM MODEL — CORRECTED (No SMOTE — dataset pre-balanced)
# Saves: best_symptom_model.keras, final_symptom_model.keras, scaler, encoder
# Run on Colab GPU. Dataset: symbipredict_2022.csv (4961 samples, 132 features, 41 classes, 121/class)

import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
import keras, os, pickle, shutil
from keras.models import Model
from keras.layers import (Input, Dense, Dropout, Conv1D, Flatten, LSTM,
                          Bidirectional, Attention, concatenate, BatchNormalization)
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.utils import to_categorical
from keras.losses import CategoricalCrossentropy
from keras.metrics import CategoricalAccuracy
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import (classification_report, confusion_matrix, f1_score,
                             recall_score, top_k_accuracy_score, roc_auc_score,
                             roc_curve, auc as sk_auc)
import warnings; warnings.filterwarnings('ignore')
for d in ['/content/saved_models','/content/figures','/content/results']: os.makedirs(d,exist_ok=True)

def ece_full(y_true, y_prob, n_bins=15):
    c=np.max(y_prob,1); p=np.argmax(y_prob,1); a=(p==y_true).astype(float)
    ece=0.0; ba,bc,bn=[],[],[]
    bnd=np.linspace(0,1,n_bins+1)
    for i in range(n_bins):
        bl,bu=bnd[i],bnd[i+1]
        m=(c>=bl)&(c<=bu) if i==n_bins-1 else (c>=bl)&(c<bu)
        cnt=np.sum(m)
        if cnt>0:
            acc=np.mean(a[m]); conf=np.mean(c[m])
            ece+=np.abs(conf-acc)*(cnt/len(c))
            ba.append(acc); bc.append(conf); bn.append(cnt)
    return ece, np.array(ba), np.array(bc), np.array(bn)

def brier_multi(yo,yp): return np.mean(np.sum((yp-yo)**2,1))

class TestCB(keras.callbacks.Callback):
    def __init__(s,Xt,yt): super().__init__(); s.Xt=Xt; s.yt=yt; s.tl=[]; s.ta=[]
    def on_epoch_end(s,ep,logs=None):
        l,a=s.model.evaluate(s.Xt,s.yt,verbose=0); s.tl.append(l); s.ta.append(a)

# ═══════ LOAD DATA ═══════
dataset = pd.read_csv('/content/symbipredict_2022.csv')
X_all = dataset.drop('prognosis',axis=1).values; y_raw = dataset['prognosis'].values
le = LabelEncoder(); y_all = le.fit_transform(y_raw); NC = len(le.classes_)
print(f"Dataset: {X_all.shape[0]} samples, {X_all.shape[1]} features, {NC} classes")
print(f"Balanced: {pd.Series(y_all).value_counts().unique()} samples/class — NO SMOTE NEEDED")

X_tv, X_te, y_tv, y_te = train_test_split(X_all, y_all, test_size=0.3, stratify=y_all, random_state=42)
print(f"Train+Val: {X_tv.shape[0]} | Test: {X_te.shape[0]}")

# Exact disease names (note trailing spaces on Diabetes and Hypertension)
ACUTE_LABELS = ['Heart Attack','Pneumonia','Tuberculosis','Typhoid','Hepatitis E',
                'Dengue','Malaria','Jaundice','Paralysis (brain hemorrhage)',
                'Alcoholic Hepatitis','Drug Reaction','Gastroenteritis']
ACUTE_CRITICAL = ['Heart Attack','Paralysis (brain hemorrhage)','AIDS']
ACUTE_MODERATE = ['Malaria','Dengue','Typhoid','Hepatitis E','Pneumonia',
                  'Tuberculosis','Alcoholic Hepatitis','Drug Reaction']
CHRONIC = ['Diabetes ','Hypertension ','Arthritis','Hypothyroidism',
           'Hyperthyroidism','Hypoglycemia','Osteoarthritis',
           'Cervical Spondylosis','Bronchial Asthma','GERD']
acute_idx = [np.where(le.classes_==l)[0][0] for l in ACUTE_LABELS if l in le.classes_]

# ═══════ MODEL ═══════
L2R = 1e-3
def DenseNetBlock(inp,gr=24,layers=5):
    for _ in range(layers):
        x=Conv1D(gr,3,padding='same',activation='relu',kernel_regularizer=l2(L2R))(inp)
        x=BatchNormalization()(x); x=Dropout(0.5)(x); inp=concatenate([inp,x])
    return inp
def LSTMAttnBlock(inp):
    o=Bidirectional(LSTM(200,return_sequences=True,kernel_regularizer=l2(L2R)))(inp)
    return Attention()([o,o])
def build_model(shape,nc):
    i=Input(shape=shape); dn=i
    for _ in range(3): dn=DenseNetBlock(dn)
    a1=Attention()([dn,dn]); lo=a1
    for _ in range(2): lo=LSTMAttnBlock(lo)
    f=concatenate([Flatten()(a1),Flatten()(lo)])
    x=Dense(512,activation='relu',kernel_regularizer=l2(L2R))(f); x=Dropout(0.6)(x)
    x=Dense(256,activation='relu',kernel_regularizer=l2(L2R))(x); x=Dropout(0.6)(x)
    x=Dense(128,activation='relu',kernel_regularizer=l2(L2R))(x); x=Dropout(0.6)(x)
    o=Dense(nc,activation='softmax')(x)
    m=Model(i,o)
    m.compile(optimizer=Adam(1e-3), loss=CategoricalCrossentropy(), metrics=[CategoricalAccuracy(name='accuracy')])
    return m

# ═══════ 5-FOLD CV ═══════
EP,BS = 85,32
skf = StratifiedKFold(n_splits=5,shuffle=True,random_state=42)
fold_res,fold_pred,all_yt,all_yp,all_yprob=[],[],[],[],[]
agg_cm=np.zeros((NC,NC),dtype=int); best_va,best_fi=-1,-1
y_te_ohe=to_categorical(y_te,NC)

for fold,(ti,vi) in enumerate(skf.split(X_tv,y_tv)):
    print(f"\n{'='*55}\n  FOLD {fold+1}\n{'='*55}")
    Xtr,Xvl=X_tv[ti],X_tv[vi]; ytr,yvl=y_tv[ti],y_tv[vi]
    sc=StandardScaler(); Xtr=sc.fit_transform(Xtr); Xvl=sc.transform(Xvl); Xtest=sc.transform(X_te)
    # NO SMOTE — data already balanced at 121/class
    ytr_o=to_categorical(ytr,NC); yvl_o=to_categorical(yvl,NC)
    Xtr3=np.expand_dims(Xtr,-1); Xvl3=np.expand_dims(Xvl,-1); Xte3=np.expand_dims(Xtest,-1)
    mdl=build_model((Xtr3.shape[1],1),NC)
    ckpt=f'/content/saved_models/symptom_fold_{fold+1}.keras'
    tcb=TestCB(Xte3,y_te_ohe)
    h=mdl.fit(Xtr3,ytr_o,validation_data=(Xvl3,yvl_o),epochs=EP,batch_size=BS,
              callbacks=[EarlyStopping(monitor='val_loss',patience=10,restore_best_weights=True),
                         ReduceLROnPlateau(monitor='val_loss',factor=0.2,patience=3,min_lr=1e-7),
                         ModelCheckpoint(ckpt,monitor='val_accuracy',save_best_only=True,mode='max'),tcb],verbose=1)
    tl,ta=mdl.evaluate(Xte3,y_te_ohe,verbose=0)
    yp=mdl.predict(Xte3,verbose=0); ypc=np.argmax(yp,1)
    va=h.history['val_accuracy'][-1]
    if va>best_va: best_va=va; best_fi=fold
    cm=confusion_matrix(y_te,ypc,labels=range(NC)); agg_cm+=cm
    all_yt.extend(y_te); all_yp.extend(ypc); all_yprob.append(yp)
    fold_pred.append({'y_true':y_te.copy(),'y_pred_prob':yp.copy()})
    f1=f1_score(y_te,ypc,average='macro')
    t3=top_k_accuracy_score(y_te,yp,k=3); t5=top_k_accuracy_score(y_te,yp,k=5)
    ec,_,_,_=ece_full(y_te,yp); br=brier_multi(y_te_ohe,yp)
    try: auc=roc_auc_score(y_te_ohe,yp,average='macro',multi_class='ovr')
    except: auc=0.0
    se=recall_score(y_te,ypc,labels=acute_idx,average='macro',zero_division=0)
    npvs=[]
    for idx in acute_idx:
        tp=cm[idx,idx];fn=np.sum(cm[idx,:])-tp;tn=np.sum(cm)-np.sum(cm[idx,:])-np.sum(cm[:,idx])+tp
        npvs.append(tn/(tn+fn) if (tn+fn)>0 else 0)
    npv=np.mean(npvs) if npvs else 0.0
    print(f"  Test:{ta:.4f} F1:{f1:.4f} AUC:{auc:.4f} Top3:{t3:.4f} Top5:{t5:.4f}")
    print(f"  ECE:{ec:.6f} Brier:{br:.6f} AcuteSens:{se:.4f} NPV:{npv:.4f}")
    fold_res.append({'train_loss':h.history['loss'][-1],'train_acc':h.history['accuracy'][-1],
        'val_loss':h.history['val_loss'][-1],'val_acc':va,'test_loss':tl,'test_acc':ta,
        'macro_f1':f1,'roc_auc':auc,'top3':t3,'top5':t5,'ece':ec,'brier':br,
        'sens_acute':se,'npv_acute':npv})
    fig,(a1,a2)=plt.subplots(1,2,figsize=(14,5))
    a1.plot(h.history['loss'],label='Train');a1.plot(h.history['val_loss'],label='Val')
    a1.plot(tcb.tl,label='Test');a1.set_title(f'Loss-Fold {fold+1}');a1.legend();a1.grid(alpha=0.3)
    a2.plot(h.history['accuracy'],label='Train');a2.plot(h.history['val_accuracy'],label='Val')
    a2.plot(tcb.ta,label='Test');a2.set_title(f'Acc-Fold {fold+1}');a2.legend();a2.grid(alpha=0.3)
    plt.tight_layout();plt.savefig(f'/content/figures/symptom_fold_{fold+1}.png',dpi=200);plt.show()

shutil.copy(f'/content/saved_models/symptom_fold_{best_fi+1}.keras','/content/saved_models/best_symptom_model.keras')
print(f"\n✅ Best model: Fold {best_fi+1} (Val Acc: {best_va:.4f})")

# ═══════ FINAL RETRAIN ═══════
print(f"\n{'='*55}\n  FINAL MODEL\n{'='*55}")
fsc=StandardScaler(); Xtvs=fsc.fit_transform(X_tv); Xtes=fsc.transform(X_te)
ytvo=to_categorical(y_tv,NC); Xtv3=np.expand_dims(Xtvs,-1); Xte3f=np.expand_dims(Xtes,-1)
fm=build_model((Xtv3.shape[1],1),NC)
fm.fit(Xtv3,ytvo,validation_split=0.1,epochs=EP,batch_size=BS,
       callbacks=[EarlyStopping(monitor='val_loss',patience=10,restore_best_weights=True),
                  ReduceLROnPlateau(monitor='val_loss',factor=0.2,patience=3,min_lr=1e-7)],verbose=1)
fl,fa=fm.evaluate(Xte3f,y_te_ohe,verbose=0)
print(f"  Final: Acc={fa:.4f} Loss={fl:.4f}")
fm.save('/content/saved_models/final_symptom_model.keras')
with open('/content/saved_models/symptom_scaler.pkl','wb') as f: pickle.dump(fsc,f)
with open('/content/saved_models/symptom_label_encoder.pkl','wb') as f: pickle.dump(le,f)

# ═══════ Q3 AGGREGATE ═══════
print(f"\n{'='*70}\n  Q3: SYMPTOM MODEL AGGREGATE\n{'='*70}")
MK=list(fold_res[0].keys()); rt={}
for k in MK:
    vs=[r[k] for r in fold_res]; m,s=np.mean(vs),np.std(vs,ddof=1); rt[k]={'mean':m,'std':s}
    fmt='.6f' if k in ['ece','brier'] else '.4f'
    print(f"  {k.replace('_',' ').title():<25}: {m:{fmt}} ± {s:{fmt}}")
pd.DataFrame(fold_res,index=[f'Fold {i+1}' for i in range(5)]).to_csv('/content/results/symptom_fold_metrics.csv',float_format='%.6f')
print(f"\n  CLASSIFICATION REPORT:")
print(classification_report(all_yt,all_yp,target_names=le.classes_))
plt.figure(figsize=(14,12))
sns.heatmap(agg_cm,annot=True,fmt='d',cmap='Blues',xticklabels=le.classes_,yticklabels=le.classes_)
plt.title('Symptom Model — Aggregate CM');plt.xticks(rotation=90,fontsize=7);plt.yticks(fontsize=7)
plt.tight_layout();plt.savefig('/content/figures/symptom_cm.png',dpi=300,bbox_inches='tight');plt.show()

# ROC
all_prob=np.concatenate(all_yprob);all_true=np.array(all_yt);ato=to_categorical(all_true,NC)
fpr,tpr,rd={},{},{}
for i in range(NC): fpr[i],tpr[i],_=roc_curve(ato[:,i],all_prob[:,i]);rd[i]=sk_auc(fpr[i],tpr[i])
afpr=np.unique(np.concatenate([fpr[i] for i in range(NC)]))
mtpr=np.zeros_like(afpr)
for i in range(NC): mtpr+=np.interp(afpr,fpr[i],tpr[i])
mtpr/=NC; mauc=sk_auc(afpr,mtpr)
plt.figure(figsize=(8,7))
plt.plot(afpr,mtpr,color='#2E75B6',lw=3,label=f'Macro ROC (AUC={mauc:.4f})')
plt.plot([0,1],[0,1],'k--');plt.xlabel('FPR');plt.ylabel('TPR')
plt.title('Symptom Model — ROC',fontweight='bold');plt.legend(fontsize=12);plt.grid(alpha=0.3)
plt.tight_layout();plt.savefig('/content/figures/symptom_roc.png',dpi=300,bbox_inches='tight');plt.show()

# ═══════ Q4 CALIBRATION ═══════
print(f"\n{'='*70}\n  Q4: CALIBRATION\n{'='*70}")
aq4t=np.concatenate([fp['y_true'] for fp in fold_pred])
aq4p=np.concatenate([fp['y_pred_prob'] for fp in fold_pred])
ece_a,ba,bc,bn=ece_full(aq4t,aq4p,15)
fig,(a1,a2)=plt.subplots(2,1,figsize=(8,8),gridspec_kw={'height_ratios':[3,1]},sharex=True)
a1.plot([0,1],[0,1],'k--',alpha=0.7)
a1.plot(bc,ba,'o-',color='#2E75B6',lw=2,ms=8,label=f'ECE={ece_a:.4f}')
a1.fill_between(bc,ba,bc,alpha=0.15,color='#2E75B6')
a1.set_ylabel('Observed Acc');a1.set_title('Reliability Diagram',fontweight='bold');a1.legend();a1.grid(alpha=0.3)
conf_all=np.max(aq4p,1)
a2.hist(conf_all,bins=15,range=(0,1),color='#2E75B6',alpha=0.7,edgecolor='white')
a2.set_xlabel('Confidence');a2.set_ylabel('Count');a2.grid(alpha=0.3)
plt.tight_layout();plt.savefig('/content/figures/symptom_reliability.png',dpi=300,bbox_inches='tight');plt.show()

# Threshold sweep
pred_q4=np.argmax(aq4p,1);cor_q4=(pred_q4==aq4t).astype(float);am=np.isin(aq4t,acute_idx)
sw=[]
for t in np.arange(0.50,1.00,0.025):
    mk=conf_all>=t;cov=mk.mean();ac=cor_q4[mk].mean() if mk.sum()>0 else 0
    acm=am&mk;afn=(1-cor_q4[acm].mean()) if acm.sum()>0 else 0
    sw.append({'threshold':t,'coverage':cov,'acc':ac,'acute_fn':afn,'rejection':1-cov})
sdf=pd.DataFrame(sw);sdf.to_csv('/content/results/symptom_threshold.csv',index=False)
print("  Threshold Sweep:")
for t in [0.80,0.90,0.95,0.975]:
    r=sdf.loc[(sdf['threshold']-t).abs().idxmin()]
    print(f"  θ={r['threshold']:.3f} → Cov:{r['coverage']:.4f} Acc:{r['acc']:.4f} AcFN:{r['acute_fn']:.4f}")

fig,(a1,a2)=plt.subplots(1,2,figsize=(14,5))
a1.plot(sdf['threshold'],sdf['coverage'],'b-o',ms=4,label='Coverage')
a1.plot(sdf['threshold'],sdf['acc'],'g-s',ms=4,label='Accuracy')
a1.axvline(0.95,color='red',ls='--',alpha=0.7,label='θ=0.95')
a1.legend();a1.grid(alpha=0.3);a1.set_title('Coverage vs Accuracy',fontweight='bold')
a2.plot(sdf['threshold'],sdf['acute_fn'],'r-^',ms=5,label='Acute FN')
a2.plot(sdf['threshold'],sdf['rejection'],'-D',color='orange',ms=4,label='Rejection')
a2.axvline(0.95,color='red',ls='--',alpha=0.7,label='θ=0.95')
a2.legend();a2.grid(alpha=0.3);a2.set_title('Safety',fontweight='bold')
plt.tight_layout();plt.savefig('/content/figures/symptom_threshold.png',dpi=300,bbox_inches='tight');plt.show()

# Cost analysis
cfn,cfp={},{}
for i,c in enumerate(le.classes_):
    cfp[i]=1.0
    if c in ACUTE_CRITICAL: cfn[i]=10.0
    elif c in ACUTE_MODERATE: cfn[i]=5.0
    elif c in CHRONIC: cfn[i]=2.0
    else: cfn[i]=1.0
fc=[]
for fp in fold_pred:
    yt,yp=fp['y_true'],np.argmax(fp['y_pred_prob'],1)
    cost=sum(np.sum((yt==c)&(yp!=c))*cfn[c]+np.sum((yt!=c)&(yp==c))*cfp[c] for c in range(NC))
    fc.append(cost/len(yt))
print(f"\n  Cost/sample: {np.mean(fc):.4f} ± {np.std(fc,ddof=1):.4f}")
for sn,sl in {'Acute-Critical':ACUTE_CRITICAL,'Acute-Moderate':ACUTE_MODERATE,'Chronic':CHRONIC}.items():
    si=[np.where(le.classes_==l)[0][0] for l in sl if l in le.classes_]
    if si:
        sm=np.isin(aq4t,si)
        if sm.sum()>0: print(f"    {sn}: Sens={cor_q4[sm].mean():.4f} ({sm.sum()} samples)")

print(f"\n✅ DONE! Models: /content/saved_models/ | Figures: /content/figures/ | Results: /content/results/")
# Out:
# Dataset: 4961 samples, 132 features, 41 classes
# Balanced: [121] samples/class — NO SMOTE NEEDED
# Train+Val: 3472 | Test: 1489
#
# =======================================================
#   FOLD 1
# =======================================================
# Epoch 1/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 51s 307ms/step - accuracy: 0.0432 - loss: 13.3666 - val_accuracy: 0.0748 - val_loss: 9.3324 - learning_rate: 0.0010
# Epoch 2/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 24s 275ms/step - accuracy: 0.0449 - loss: 9.0185 - val_accuracy: 0.1971 - val_loss: 8.1847 - learning_rate: 0.0010
# Epoch 3/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 196ms/step - accuracy: 0.1068 - loss: 7.7700 - val_accuracy: 0.2777 - val_loss: 7.3337 - learning_rate: 0.0010
# Epoch 4/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 21s 200ms/step - accuracy: 0.1381 - loss: 7.0337 - val_accuracy: 0.3554 - val_loss: 6.5256 - learning_rate: 0.0010
# Epoch 5/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 20s 196ms/step - accuracy: 0.1991 - loss: 6.4937 - val_accuracy: 0.4763 - val_loss: 5.8410 - learning_rate: 0.0010
# Epoch 6/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 198ms/step - accuracy: 0.2435 - loss: 6.0386 - val_accuracy: 0.5137 - val_loss: 5.2164 - learning_rate: 0.0010
# Epoch 7/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.2995 - loss: 5.6649 - val_accuracy: 0.5108 - val_loss: 4.9899 - learning_rate: 0.0010
# Epoch 8/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 207ms/step - accuracy: 0.3463 - loss: 5.3529 - val_accuracy: 0.5712 - val_loss: 4.6005 - learning_rate: 0.0010
# Epoch 9/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 14s 129ms/step - accuracy: 0.3611 - loss: 5.1022 - val_accuracy: 0.5281 - val_loss: 4.5268 - learning_rate: 0.0010
# Epoch 10/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.3928 - loss: 4.9153 - val_accuracy: 0.5309 - val_loss: 4.4429 - learning_rate: 0.0010
# Epoch 11/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.3941 - loss: 4.8235 - val_accuracy: 0.5367 - val_loss: 4.2554 - learning_rate: 0.0010
# Epoch 12/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.3977 - loss: 4.7407 - val_accuracy: 0.5568 - val_loss: 4.1924 - learning_rate: 0.0010
# Epoch 13/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - accuracy: 0.4348 - loss: 4.5437 - val_accuracy: 0.5554 - val_loss: 4.1326 - learning_rate: 0.0010
# Epoch 14/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 23s 262ms/step - accuracy: 0.4432 - loss: 4.5124 - val_accuracy: 0.5799 - val_loss: 4.0314 - learning_rate: 0.0010
# Epoch 15/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 15s 178ms/step - accuracy: 0.4768 - loss: 4.3698 - val_accuracy: 0.5856 - val_loss: 4.0017 - learning_rate: 0.0010
# Epoch 16/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 21s 238ms/step - accuracy: 0.4523 - loss: 4.4353 - val_accuracy: 0.6302 - val_loss: 3.9749 - learning_rate: 0.0010
# Epoch 17/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 36s 182ms/step - accuracy: 0.4800 - loss: 4.3485 - val_accuracy: 0.6590 - val_loss: 3.7602 - learning_rate: 0.0010
# Epoch 18/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.5150 - loss: 4.1442 - val_accuracy: 0.6345 - val_loss: 3.7426 - learning_rate: 0.0010
# Epoch 19/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 181ms/step - accuracy: 0.5212 - loss: 4.0658 - val_accuracy: 0.6791 - val_loss: 3.5764 - learning_rate: 0.0010
# Epoch 20/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 126ms/step - accuracy: 0.5076 - loss: 4.1018 - val_accuracy: 0.6590 - val_loss: 3.6894 - learning_rate: 0.0010
# Epoch 21/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 196ms/step - accuracy: 0.5168 - loss: 4.1838 - val_accuracy: 0.7050 - val_loss: 3.6184 - learning_rate: 0.0010
# Epoch 22/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 127ms/step - accuracy: 0.5432 - loss: 4.1369 - val_accuracy: 0.6820 - val_loss: 3.7483 - learning_rate: 0.0010
# Epoch 23/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 194ms/step - accuracy: 0.5704 - loss: 4.0714 - val_accuracy: 0.7079 - val_loss: 3.5912 - learning_rate: 2.0000e-04
# Epoch 24/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.5578 - loss: 4.0349 - val_accuracy: 0.7079 - val_loss: 3.4922 - learning_rate: 2.0000e-04
# Epoch 25/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 21s 130ms/step - accuracy: 0.5842 - loss: 3.8791 - val_accuracy: 0.7079 - val_loss: 3.4003 - learning_rate: 2.0000e-04
# Epoch 26/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.5885 - loss: 3.7636 - val_accuracy: 0.7079 - val_loss: 3.2881 - learning_rate: 2.0000e-04
# Epoch 27/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 23s 262ms/step - accuracy: 0.5930 - loss: 3.6875 - val_accuracy: 0.7209 - val_loss: 3.2152 - learning_rate: 2.0000e-04
# Epoch 28/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 15s 178ms/step - accuracy: 0.6044 - loss: 3.5343 - val_accuracy: 0.7223 - val_loss: 3.1308 - learning_rate: 2.0000e-04
# Epoch 29/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.6177 - loss: 3.4220 - val_accuracy: 0.7079 - val_loss: 3.0533 - learning_rate: 2.0000e-04
# Epoch 30/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 205ms/step - accuracy: 0.6251 - loss: 3.3320 - val_accuracy: 0.7266 - val_loss: 2.9814 - learning_rate: 2.0000e-04
# Epoch 31/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.6213 - loss: 3.2649 - val_accuracy: 0.7094 - val_loss: 2.9140 - learning_rate: 2.0000e-04
# Epoch 32/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.6167 - loss: 3.2169 - val_accuracy: 0.7079 - val_loss: 2.8463 - learning_rate: 2.0000e-04
# Epoch 33/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 23s 265ms/step - accuracy: 0.6314 - loss: 3.1161 - val_accuracy: 0.7698 - val_loss: 2.7631 - learning_rate: 2.0000e-04
# Epoch 34/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.6338 - loss: 3.0624 - val_accuracy: 0.7626 - val_loss: 2.6908 - learning_rate: 2.0000e-04
# Epoch 35/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 186ms/step - accuracy: 0.6590 - loss: 2.9607 - val_accuracy: 0.7712 - val_loss: 2.6038 - learning_rate: 2.0000e-04
# Epoch 36/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 202ms/step - accuracy: 0.6606 - loss: 2.8588 - val_accuracy: 0.7899 - val_loss: 2.5267 - learning_rate: 2.0000e-04
# Epoch 37/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.6662 - loss: 2.7630 - val_accuracy: 0.7957 - val_loss: 2.4521 - learning_rate: 2.0000e-04
# Epoch 38/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.6618 - loss: 2.7349 - val_accuracy: 0.7856 - val_loss: 2.3680 - learning_rate: 2.0000e-04
# Epoch 39/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.6660 - loss: 2.6969 - val_accuracy: 0.7827 - val_loss: 2.3026 - learning_rate: 2.0000e-04
# Epoch 40/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.6768 - loss: 2.5888 - val_accuracy: 0.7827 - val_loss: 2.2562 - learning_rate: 2.0000e-04
# Epoch 41/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.6741 - loss: 2.5722 - val_accuracy: 0.7928 - val_loss: 2.2093 - learning_rate: 2.0000e-04
# Epoch 42/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.6749 - loss: 2.5152 - val_accuracy: 0.7856 - val_loss: 2.1463 - learning_rate: 2.0000e-04
# Epoch 43/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.6768 - loss: 2.4446 - val_accuracy: 0.7856 - val_loss: 2.0767 - learning_rate: 2.0000e-04
# Epoch 44/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.6815 - loss: 2.3769 - val_accuracy: 0.7799 - val_loss: 2.0522 - learning_rate: 2.0000e-04
# Epoch 45/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 24s 281ms/step - accuracy: 0.6894 - loss: 2.3465 - val_accuracy: 0.8058 - val_loss: 1.9629 - learning_rate: 2.0000e-04
# Epoch 46/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.6967 - loss: 2.2758 - val_accuracy: 0.7856 - val_loss: 1.9143 - learning_rate: 2.0000e-04
# Epoch 47/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.7090 - loss: 2.2106 - val_accuracy: 0.8058 - val_loss: 1.8810 - learning_rate: 2.0000e-04
# Epoch 48/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.7175 - loss: 2.1229 - val_accuracy: 0.8058 - val_loss: 1.8360 - learning_rate: 2.0000e-04
# Epoch 49/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.7150 - loss: 2.1146 - val_accuracy: 0.8058 - val_loss: 1.8087 - learning_rate: 2.0000e-04
# Epoch 50/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.7192 - loss: 2.0802 - val_accuracy: 0.7871 - val_loss: 1.7831 - learning_rate: 2.0000e-04
# Epoch 51/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 213ms/step - accuracy: 0.7021 - loss: 2.1106 - val_accuracy: 0.8201 - val_loss: 1.7610 - learning_rate: 2.0000e-04
# Epoch 52/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.7247 - loss: 2.0226 - val_accuracy: 0.8230 - val_loss: 1.7221 - learning_rate: 2.0000e-04
# Epoch 53/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.7506 - loss: 1.9464 - val_accuracy: 0.8058 - val_loss: 1.6897 - learning_rate: 2.0000e-04
# Epoch 54/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 195ms/step - accuracy: 0.7286 - loss: 1.9276 - val_accuracy: 0.8273 - val_loss: 1.6599 - learning_rate: 2.0000e-04
# Epoch 55/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 180ms/step - accuracy: 0.7594 - loss: 1.8612 - val_accuracy: 0.8317 - val_loss: 1.6193 - learning_rate: 2.0000e-04
# Epoch 56/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 197ms/step - accuracy: 0.7474 - loss: 1.8495 - val_accuracy: 0.8489 - val_loss: 1.5888 - learning_rate: 2.0000e-04
# Epoch 57/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.7735 - loss: 1.7806 - val_accuracy: 0.8302 - val_loss: 1.5684 - learning_rate: 2.0000e-04
# Epoch 58/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.7647 - loss: 1.8144 - val_accuracy: 0.8446 - val_loss: 1.5585 - learning_rate: 2.0000e-04
# Epoch 59/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.7715 - loss: 1.8003 - val_accuracy: 0.8561 - val_loss: 1.5335 - learning_rate: 2.0000e-04
# Epoch 60/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - accuracy: 0.7669 - loss: 1.7930 - val_accuracy: 0.8547 - val_loss: 1.4910 - learning_rate: 2.0000e-04
# Epoch 61/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 194ms/step - accuracy: 0.7882 - loss: 1.7690 - val_accuracy: 0.8964 - val_loss: 1.4646 - learning_rate: 2.0000e-04
# Epoch 62/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 200ms/step - accuracy: 0.7834 - loss: 1.6950 - val_accuracy: 0.8978 - val_loss: 1.4180 - learning_rate: 2.0000e-04
# Epoch 63/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 196ms/step - accuracy: 0.7880 - loss: 1.6778 - val_accuracy: 0.8993 - val_loss: 1.3808 - learning_rate: 2.0000e-04
# Epoch 64/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 20s 235ms/step - accuracy: 0.8074 - loss: 1.5862 - val_accuracy: 0.9022 - val_loss: 1.3549 - learning_rate: 2.0000e-04
# Epoch 65/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 194ms/step - accuracy: 0.8075 - loss: 1.6029 - val_accuracy: 0.9050 - val_loss: 1.3529 - learning_rate: 2.0000e-04
# Epoch 66/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 200ms/step - accuracy: 0.8143 - loss: 1.6106 - val_accuracy: 0.9180 - val_loss: 1.3364 - learning_rate: 2.0000e-04
# Epoch 67/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 27s 317ms/step - accuracy: 0.8162 - loss: 1.5823 - val_accuracy: 0.9252 - val_loss: 1.3189 - learning_rate: 2.0000e-04
# Epoch 68/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 15s 178ms/step - accuracy: 0.8247 - loss: 1.5932 - val_accuracy: 0.9266 - val_loss: 1.3048 - learning_rate: 2.0000e-04
# Epoch 69/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 203ms/step - accuracy: 0.8312 - loss: 1.5398 - val_accuracy: 0.9496 - val_loss: 1.2701 - learning_rate: 2.0000e-04
# Epoch 70/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.8455 - loss: 1.5032 - val_accuracy: 0.9496 - val_loss: 1.2661 - learning_rate: 2.0000e-04
# Epoch 71/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 25s 180ms/step - accuracy: 0.8482 - loss: 1.5065 - val_accuracy: 0.9511 - val_loss: 1.2459 - learning_rate: 2.0000e-04
# Epoch 72/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 127ms/step - accuracy: 0.8422 - loss: 1.5655 - val_accuracy: 0.9511 - val_loss: 1.2372 - learning_rate: 2.0000e-04
# Epoch 73/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.8674 - loss: 1.4933 - val_accuracy: 0.9511 - val_loss: 1.2227 - learning_rate: 2.0000e-04
# Epoch 74/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 199ms/step - accuracy: 0.8658 - loss: 1.4499 - val_accuracy: 0.9755 - val_loss: 1.1774 - learning_rate: 2.0000e-04
# Epoch 75/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.8843 - loss: 1.4192 - val_accuracy: 0.9511 - val_loss: 1.1716 - learning_rate: 2.0000e-04
# Epoch 76/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.8821 - loss: 1.4054 - val_accuracy: 0.9755 - val_loss: 1.1658 - learning_rate: 2.0000e-04
# Epoch 77/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 125ms/step - accuracy: 0.8786 - loss: 1.4584 - val_accuracy: 0.9755 - val_loss: 1.1745 - learning_rate: 2.0000e-04
# Epoch 78/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - accuracy: 0.9065 - loss: 1.3626 - val_accuracy: 0.9511 - val_loss: 1.1505 - learning_rate: 2.0000e-04
# Epoch 79/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.9026 - loss: 1.3413 - val_accuracy: 0.9755 - val_loss: 1.1544 - learning_rate: 2.0000e-04
# Epoch 80/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.9072 - loss: 1.3313 - val_accuracy: 0.9755 - val_loss: 1.1301 - learning_rate: 2.0000e-04
# Epoch 81/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.8987 - loss: 1.3615 - val_accuracy: 0.9755 - val_loss: 1.1199 - learning_rate: 2.0000e-04
# Epoch 82/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.9196 - loss: 1.3440 - val_accuracy: 0.9755 - val_loss: 1.1156 - learning_rate: 2.0000e-04
# Epoch 83/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 19s 225ms/step - accuracy: 0.9290 - loss: 1.2819 - val_accuracy: 1.0000 - val_loss: 1.1045 - learning_rate: 2.0000e-04
# Epoch 84/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - accuracy: 0.9118 - loss: 1.3446 - val_accuracy: 1.0000 - val_loss: 1.0974 - learning_rate: 2.0000e-04
# Epoch 85/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 126ms/step - accuracy: 0.9097 - loss: 1.3065 - val_accuracy: 0.9755 - val_loss: 1.1152 - learning_rate: 2.0000e-04
#   Test:1.0000 F1:1.0000 AUC:0.9999 Top3:1.0000 Top5:1.0000
#   ECE:0.041781 Brier:0.034492 AcuteSens:1.0000 NPV:1.0000
# =======================================================
#   FOLD 2
# =======================================================
# Epoch 1/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 32s 196ms/step - accuracy: 0.0461 - loss: 13.6139 - val_accuracy: 0.0245 - val_loss: 9.4021 - learning_rate: 0.0010
# Epoch 2/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.0351 - loss: 9.0821 - val_accuracy: 0.0245 - val_loss: 8.2252 - learning_rate: 0.0010
# Epoch 3/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 203ms/step - accuracy: 0.0534 - loss: 7.9510 - val_accuracy: 0.1468 - val_loss: 7.4191 - learning_rate: 0.0010
# Epoch 4/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 200ms/step - accuracy: 0.0748 - loss: 7.2451 - val_accuracy: 0.3122 - val_loss: 6.6513 - learning_rate: 0.0010
# Epoch 5/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.1289 - loss: 6.7650 - val_accuracy: 0.4230 - val_loss: 6.1594 - learning_rate: 0.0010
# Epoch 6/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 184ms/step - accuracy: 0.1772 - loss: 6.3334 - val_accuracy: 0.4403 - val_loss: 5.6732 - learning_rate: 0.0010
# Epoch 7/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 198ms/step - accuracy: 0.2534 - loss: 5.9256 - val_accuracy: 0.5424 - val_loss: 5.1812 - learning_rate: 0.0010
# Epoch 8/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 24s 279ms/step - accuracy: 0.3186 - loss: 5.6251 - val_accuracy: 0.6029 - val_loss: 4.9461 - learning_rate: 0.0010
# Epoch 9/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 180ms/step - accuracy: 0.3651 - loss: 5.3660 - val_accuracy: 0.6360 - val_loss: 4.5551 - learning_rate: 0.0010
# Epoch 10/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 196ms/step - accuracy: 0.3902 - loss: 5.1641 - val_accuracy: 0.6748 - val_loss: 4.4472 - learning_rate: 0.0010
# Epoch 11/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.4002 - loss: 5.1057 - val_accuracy: 0.6561 - val_loss: 4.3662 - learning_rate: 0.0010
# Epoch 12/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.4472 - loss: 4.9598 - val_accuracy: 0.6561 - val_loss: 4.3519 - learning_rate: 0.0010
# Epoch 13/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 25s 285ms/step - accuracy: 0.4678 - loss: 4.8739 - val_accuracy: 0.6964 - val_loss: 4.2192 - learning_rate: 0.0010
# Epoch 14/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.4760 - loss: 4.7100 - val_accuracy: 0.6806 - val_loss: 4.0051 - learning_rate: 0.0010
# Epoch 15/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.4885 - loss: 4.6118 - val_accuracy: 0.6835 - val_loss: 3.9261 - learning_rate: 0.0010
# Epoch 16/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.5192 - loss: 4.4707 - val_accuracy: 0.6835 - val_loss: 3.8144 - learning_rate: 0.0010
# Epoch 17/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 127ms/step - accuracy: 0.5127 - loss: 4.4145 - val_accuracy: 0.6518 - val_loss: 4.0045 - learning_rate: 0.0010
# Epoch 18/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.5310 - loss: 4.3996 - val_accuracy: 0.6820 - val_loss: 3.7455 - learning_rate: 0.0010
# Epoch 19/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.5526 - loss: 4.2446 - val_accuracy: 0.6835 - val_loss: 3.6053 - learning_rate: 0.0010
# Epoch 20/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.5754 - loss: 4.1470 - val_accuracy: 0.6835 - val_loss: 3.5621 - learning_rate: 0.0010
# Epoch 21/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 23s 263ms/step - accuracy: 0.5704 - loss: 4.0502 - val_accuracy: 0.7079 - val_loss: 3.4686 - learning_rate: 0.0010
# Epoch 22/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 127ms/step - accuracy: 0.5735 - loss: 3.9910 - val_accuracy: 0.6604 - val_loss: 3.4922 - learning_rate: 0.0010
# Epoch 23/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.5942 - loss: 3.8478 - val_accuracy: 0.7065 - val_loss: 3.3820 - learning_rate: 0.0010
# Epoch 24/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - accuracy: 0.5778 - loss: 3.8773 - val_accuracy: 0.7007 - val_loss: 3.4565 - learning_rate: 0.0010
# Epoch 25/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 180ms/step - accuracy: 0.5721 - loss: 3.9401 - val_accuracy: 0.7338 - val_loss: 3.4412 - learning_rate: 0.0010
# Epoch 26/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 126ms/step - accuracy: 0.5697 - loss: 4.0033 - val_accuracy: 0.7022 - val_loss: 3.6116 - learning_rate: 0.0010
# Epoch 27/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 126ms/step - accuracy: 0.5931 - loss: 3.9551 - val_accuracy: 0.7065 - val_loss: 3.4861 - learning_rate: 2.0000e-04
# Epoch 28/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.6206 - loss: 3.8046 - val_accuracy: 0.7237 - val_loss: 3.3816 - learning_rate: 2.0000e-04
# Epoch 29/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.6128 - loss: 3.7227 - val_accuracy: 0.7122 - val_loss: 3.2968 - learning_rate: 2.0000e-04
# Epoch 30/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 180ms/step - accuracy: 0.6215 - loss: 3.6191 - val_accuracy: 0.7496 - val_loss: 3.2118 - learning_rate: 2.0000e-04
# Epoch 31/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.6423 - loss: 3.4961 - val_accuracy: 0.7324 - val_loss: 3.1222 - learning_rate: 2.0000e-04
# Epoch 32/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 204ms/step - accuracy: 0.6354 - loss: 3.4485 - val_accuracy: 0.7755 - val_loss: 3.0205 - learning_rate: 2.0000e-04
# Epoch 33/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.6646 - loss: 3.2228 - val_accuracy: 0.7568 - val_loss: 2.9277 - learning_rate: 2.0000e-04
# Epoch 34/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.6624 - loss: 3.1743 - val_accuracy: 0.7626 - val_loss: 2.8441 - learning_rate: 2.0000e-04
# Epoch 35/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.6672 - loss: 3.0983 - val_accuracy: 0.7583 - val_loss: 2.7602 - learning_rate: 2.0000e-04
# Epoch 36/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.6739 - loss: 3.0328 - val_accuracy: 0.7655 - val_loss: 2.6808 - learning_rate: 2.0000e-04
# Epoch 37/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.6842 - loss: 2.8952 - val_accuracy: 0.7755 - val_loss: 2.5999 - learning_rate: 2.0000e-04
# Epoch 38/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.6897 - loss: 2.8084 - val_accuracy: 0.7626 - val_loss: 2.5465 - learning_rate: 2.0000e-04
# Epoch 39/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.6901 - loss: 2.7491 - val_accuracy: 0.7655 - val_loss: 2.4679 - learning_rate: 2.0000e-04
# Epoch 40/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 24s 281ms/step - accuracy: 0.6666 - loss: 2.7729 - val_accuracy: 0.7914 - val_loss: 2.4105 - learning_rate: 2.0000e-04
# Epoch 41/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.6832 - loss: 2.6479 - val_accuracy: 0.7885 - val_loss: 2.3457 - learning_rate: 2.0000e-04
# Epoch 42/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 181ms/step - accuracy: 0.6870 - loss: 2.5459 - val_accuracy: 0.8043 - val_loss: 2.2727 - learning_rate: 2.0000e-04
# Epoch 43/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.6840 - loss: 2.5197 - val_accuracy: 0.8043 - val_loss: 2.2088 - learning_rate: 2.0000e-04
# Epoch 44/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - accuracy: 0.7030 - loss: 2.4515 - val_accuracy: 0.8043 - val_loss: 2.1542 - learning_rate: 2.0000e-04
# Epoch 45/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 182ms/step - accuracy: 0.7034 - loss: 2.4296 - val_accuracy: 0.8691 - val_loss: 2.0965 - learning_rate: 2.0000e-04
# Epoch 46/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.7157 - loss: 2.3237 - val_accuracy: 0.8273 - val_loss: 2.0319 - learning_rate: 2.0000e-04
# Epoch 47/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.7019 - loss: 2.2774 - val_accuracy: 0.8072 - val_loss: 1.9743 - learning_rate: 2.0000e-04
# Epoch 48/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.7286 - loss: 2.1695 - val_accuracy: 0.8216 - val_loss: 1.9274 - learning_rate: 2.0000e-04
# Epoch 49/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.7402 - loss: 2.1300 - val_accuracy: 0.8043 - val_loss: 1.8815 - learning_rate: 2.0000e-04
# Epoch 50/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.7414 - loss: 2.0908 - val_accuracy: 0.8058 - val_loss: 1.8366 - learning_rate: 2.0000e-04
# Epoch 51/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.7514 - loss: 2.0085 - val_accuracy: 0.8086 - val_loss: 1.8012 - learning_rate: 2.0000e-04
# Epoch 52/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.7406 - loss: 2.0077 - val_accuracy: 0.8216 - val_loss: 1.7517 - learning_rate: 2.0000e-04
# Epoch 53/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.7308 - loss: 2.0331 - val_accuracy: 0.8518 - val_loss: 1.7228 - learning_rate: 2.0000e-04
# Epoch 54/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.7556 - loss: 1.9325 - val_accuracy: 0.8302 - val_loss: 1.6682 - learning_rate: 2.0000e-04
# Epoch 55/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.7467 - loss: 1.9163 - val_accuracy: 0.8302 - val_loss: 1.6298 - learning_rate: 2.0000e-04
# Epoch 56/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.7497 - loss: 1.9000 - val_accuracy: 0.8302 - val_loss: 1.5855 - learning_rate: 2.0000e-04
# Epoch 57/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 38s 328ms/step - accuracy: 0.7731 - loss: 1.8203 - val_accuracy: 0.8806 - val_loss: 1.5389 - learning_rate: 2.0000e-04
# Epoch 58/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.7800 - loss: 1.7751 - val_accuracy: 0.8791 - val_loss: 1.5144 - learning_rate: 2.0000e-04
# Epoch 59/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 27s 317ms/step - accuracy: 0.7893 - loss: 1.7356 - val_accuracy: 0.9036 - val_loss: 1.4693 - learning_rate: 2.0000e-04
# Epoch 60/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.7914 - loss: 1.7259 - val_accuracy: 0.8863 - val_loss: 1.4224 - learning_rate: 2.0000e-04
# Epoch 61/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 182ms/step - accuracy: 0.7814 - loss: 1.7177 - val_accuracy: 0.9468 - val_loss: 1.3968 - learning_rate: 2.0000e-04
# Epoch 62/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.7877 - loss: 1.7211 - val_accuracy: 0.9266 - val_loss: 1.3701 - learning_rate: 2.0000e-04
# Epoch 63/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.8113 - loss: 1.6567 - val_accuracy: 0.9281 - val_loss: 1.3287 - learning_rate: 2.0000e-04
# Epoch 64/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 204ms/step - accuracy: 0.8112 - loss: 1.6222 - val_accuracy: 0.9741 - val_loss: 1.2971 - learning_rate: 2.0000e-04
# Epoch 65/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8246 - loss: 1.6032 - val_accuracy: 0.9741 - val_loss: 1.2660 - learning_rate: 2.0000e-04
# Epoch 66/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8575 - loss: 1.5540 - val_accuracy: 0.9525 - val_loss: 1.2654 - learning_rate: 2.0000e-04
# Epoch 67/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8485 - loss: 1.5792 - val_accuracy: 0.9741 - val_loss: 1.2427 - learning_rate: 2.0000e-04
# Epoch 68/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.8641 - loss: 1.5353 - val_accuracy: 0.9727 - val_loss: 1.2247 - learning_rate: 2.0000e-04
# Epoch 69/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - accuracy: 0.8697 - loss: 1.5123 - val_accuracy: 0.9712 - val_loss: 1.2026 - learning_rate: 2.0000e-04
# Epoch 70/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.8716 - loss: 1.4807 - val_accuracy: 0.9727 - val_loss: 1.1819 - learning_rate: 2.0000e-04
# Epoch 71/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 26s 306ms/step - accuracy: 0.8706 - loss: 1.4990 - val_accuracy: 0.9755 - val_loss: 1.1617 - learning_rate: 2.0000e-04
# Epoch 72/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 206ms/step - accuracy: 0.8663 - loss: 1.4911 - val_accuracy: 0.9957 - val_loss: 1.1729 - learning_rate: 2.0000e-04
# Epoch 73/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - accuracy: 0.8849 - loss: 1.4759 - val_accuracy: 0.9957 - val_loss: 1.1821 - learning_rate: 2.0000e-04
# Epoch 74/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.8943 - loss: 1.4621 - val_accuracy: 1.0000 - val_loss: 1.1812 - learning_rate: 2.0000e-04
# Epoch 75/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.8996 - loss: 1.4559 - val_accuracy: 1.0000 - val_loss: 1.1642 - learning_rate: 4.0000e-05
# Epoch 76/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.9135 - loss: 1.4105 - val_accuracy: 1.0000 - val_loss: 1.1479 - learning_rate: 4.0000e-05
# Epoch 77/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.9215 - loss: 1.3489 - val_accuracy: 1.0000 - val_loss: 1.1319 - learning_rate: 4.0000e-05
# Epoch 78/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.9199 - loss: 1.3531 - val_accuracy: 1.0000 - val_loss: 1.1163 - learning_rate: 4.0000e-05
# Epoch 79/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.9254 - loss: 1.3128 - val_accuracy: 1.0000 - val_loss: 1.0997 - learning_rate: 4.0000e-05
# Epoch 80/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.9211 - loss: 1.3027 - val_accuracy: 1.0000 - val_loss: 1.0871 - learning_rate: 4.0000e-05
# Epoch 81/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.9201 - loss: 1.3393 - val_accuracy: 1.0000 - val_loss: 1.0707 - learning_rate: 4.0000e-05
# Epoch 82/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.9339 - loss: 1.2687 - val_accuracy: 1.0000 - val_loss: 1.0573 - learning_rate: 4.0000e-05
# Epoch 83/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - accuracy: 0.9327 - loss: 1.2534 - val_accuracy: 1.0000 - val_loss: 1.0426 - learning_rate: 4.0000e-05
# Epoch 84/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.9256 - loss: 1.2408 - val_accuracy: 1.0000 - val_loss: 1.0309 - learning_rate: 4.0000e-05
# Epoch 85/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.9325 - loss: 1.2577 - val_accuracy: 1.0000 - val_loss: 1.0199 - learning_rate: 4.0000e-05
#   Test:1.0000 F1:1.0000 AUC:1.0000 Top3:1.0000 Top5:1.0000
#   ECE:0.026202 Brier:0.015058 AcuteSens:1.0000 NPV:1.0000
# =======================================================
#   FOLD 3
# =======================================================
# Epoch 1/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 36s 240ms/step - accuracy: 0.0452 - loss: 14.7743 - val_accuracy: 0.0677 - val_loss: 9.8353 - learning_rate: 0.0010
# Epoch 2/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 37s 199ms/step - accuracy: 0.0371 - loss: 9.6067 - val_accuracy: 0.1153 - val_loss: 8.7336 - learning_rate: 0.0010
# Epoch 3/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 198ms/step - accuracy: 0.0677 - loss: 8.4471 - val_accuracy: 0.2046 - val_loss: 7.7076 - learning_rate: 0.0010
# Epoch 4/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 205ms/step - accuracy: 0.1187 - loss: 7.7259 - val_accuracy: 0.2651 - val_loss: 7.0852 - learning_rate: 0.0010
# Epoch 5/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 185ms/step - accuracy: 0.1472 - loss: 7.1644 - val_accuracy: 0.3646 - val_loss: 6.3755 - learning_rate: 0.0010
# Epoch 6/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 22s 199ms/step - accuracy: 0.2007 - loss: 6.7036 - val_accuracy: 0.5029 - val_loss: 6.0008 - learning_rate: 0.0010
# Epoch 7/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.2446 - loss: 6.5370 - val_accuracy: 0.4755 - val_loss: 5.8680 - learning_rate: 0.0010
# Epoch 8/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 198ms/step - accuracy: 0.2988 - loss: 6.3570 - val_accuracy: 0.5504 - val_loss: 5.6273 - learning_rate: 0.0010
# Epoch 9/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 19s 225ms/step - accuracy: 0.3502 - loss: 6.0507 - val_accuracy: 0.6153 - val_loss: 5.3866 - learning_rate: 0.0010
# Epoch 10/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 21s 239ms/step - accuracy: 0.3866 - loss: 5.8499 - val_accuracy: 0.6383 - val_loss: 5.2900 - learning_rate: 0.0010
# Epoch 11/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 195ms/step - accuracy: 0.4468 - loss: 5.6333 - val_accuracy: 0.6571 - val_loss: 5.0325 - learning_rate: 0.0010
# Epoch 12/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 186ms/step - accuracy: 0.4709 - loss: 5.4461 - val_accuracy: 0.7853 - val_loss: 4.8667 - learning_rate: 0.0010
# Epoch 13/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 182ms/step - accuracy: 0.4939 - loss: 5.4756 - val_accuracy: 0.8040 - val_loss: 4.5069 - learning_rate: 0.0010
# Epoch 14/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.5110 - loss: 5.3179 - val_accuracy: 0.8012 - val_loss: 4.4090 - learning_rate: 0.0010
# Epoch 15/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 203ms/step - accuracy: 0.5678 - loss: 5.0621 - val_accuracy: 0.8141 - val_loss: 4.3715 - learning_rate: 0.0010
# Epoch 16/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.5513 - loss: 5.0754 - val_accuracy: 0.8112 - val_loss: 4.2748 - learning_rate: 0.0010
# Epoch 17/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 24s 274ms/step - accuracy: 0.5744 - loss: 5.0502 - val_accuracy: 0.8256 - val_loss: 4.1776 - learning_rate: 0.0010
# Epoch 18/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 182ms/step - accuracy: 0.6107 - loss: 4.8606 - val_accuracy: 0.8271 - val_loss: 4.0872 - learning_rate: 0.0010
# Epoch 19/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 182ms/step - accuracy: 0.6278 - loss: 4.6564 - val_accuracy: 0.8573 - val_loss: 3.9919 - learning_rate: 0.0010
# Epoch 20/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - accuracy: 0.6508 - loss: 4.6381 - val_accuracy: 0.8473 - val_loss: 3.8818 - learning_rate: 0.0010
# Epoch 21/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - accuracy: 0.6676 - loss: 4.5687 - val_accuracy: 0.8386 - val_loss: 3.9615 - learning_rate: 0.0010
# Epoch 22/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 24s 277ms/step - accuracy: 0.6705 - loss: 4.5697 - val_accuracy: 0.8631 - val_loss: 4.0197 - learning_rate: 0.0010
# Epoch 23/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 19s 220ms/step - accuracy: 0.6827 - loss: 4.6036 - val_accuracy: 0.8660 - val_loss: 3.9807 - learning_rate: 0.0010
# Epoch 24/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 28s 322ms/step - accuracy: 0.6723 - loss: 4.5609 - val_accuracy: 0.8718 - val_loss: 3.8520 - learning_rate: 2.0000e-04
# Epoch 25/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 205ms/step - accuracy: 0.7184 - loss: 4.3099 - val_accuracy: 0.8732 - val_loss: 3.7075 - learning_rate: 2.0000e-04
# Epoch 26/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 212ms/step - accuracy: 0.7229 - loss: 4.1950 - val_accuracy: 0.8761 - val_loss: 3.6209 - learning_rate: 2.0000e-04
# Epoch 27/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 23s 270ms/step - accuracy: 0.7078 - loss: 4.1267 - val_accuracy: 0.8775 - val_loss: 3.5250 - learning_rate: 2.0000e-04
# Epoch 28/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.7182 - loss: 4.0230 - val_accuracy: 0.8761 - val_loss: 3.4250 - learning_rate: 2.0000e-04
# Epoch 29/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 183ms/step - accuracy: 0.7265 - loss: 3.9406 - val_accuracy: 0.8790 - val_loss: 3.3287 - learning_rate: 2.0000e-04
# Epoch 30/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.7300 - loss: 3.7987 - val_accuracy: 0.8790 - val_loss: 3.2416 - learning_rate: 2.0000e-04
# Epoch 31/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.7622 - loss: 3.6261 - val_accuracy: 0.8775 - val_loss: 3.1562 - learning_rate: 2.0000e-04
# Epoch 32/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 182ms/step - accuracy: 0.7576 - loss: 3.5378 - val_accuracy: 0.8948 - val_loss: 3.0512 - learning_rate: 2.0000e-04
# Epoch 33/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 181ms/step - accuracy: 0.7640 - loss: 3.4265 - val_accuracy: 0.9452 - val_loss: 2.9492 - learning_rate: 2.0000e-04
# Epoch 34/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 23s 264ms/step - accuracy: 0.7633 - loss: 3.3501 - val_accuracy: 0.9481 - val_loss: 2.8487 - learning_rate: 2.0000e-04
# Epoch 35/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.7705 - loss: 3.2386 - val_accuracy: 0.9179 - val_loss: 2.7657 - learning_rate: 2.0000e-04
# Epoch 36/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.7633 - loss: 3.1647 - val_accuracy: 0.9424 - val_loss: 2.6902 - learning_rate: 2.0000e-04
# Epoch 37/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.7726 - loss: 3.1224 - val_accuracy: 0.9308 - val_loss: 2.6021 - learning_rate: 2.0000e-04
# Epoch 38/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.7779 - loss: 3.0092 - val_accuracy: 0.9337 - val_loss: 2.5440 - learning_rate: 2.0000e-04
# Epoch 39/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.7850 - loss: 2.9363 - val_accuracy: 0.9438 - val_loss: 2.4542 - learning_rate: 2.0000e-04
# Epoch 40/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.7891 - loss: 2.8429 - val_accuracy: 0.9308 - val_loss: 2.3881 - learning_rate: 2.0000e-04
# Epoch 41/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.8034 - loss: 2.7775 - val_accuracy: 0.9265 - val_loss: 2.3105 - learning_rate: 2.0000e-04
# Epoch 42/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - accuracy: 0.8169 - loss: 2.6520 - val_accuracy: 0.9337 - val_loss: 2.2448 - learning_rate: 2.0000e-04
# Epoch 43/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.8117 - loss: 2.6195 - val_accuracy: 0.9352 - val_loss: 2.1865 - learning_rate: 2.0000e-04
# Epoch 44/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 212ms/step - accuracy: 0.8215 - loss: 2.5011 - val_accuracy: 0.9510 - val_loss: 2.1394 - learning_rate: 2.0000e-04
# Epoch 45/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - accuracy: 0.7986 - loss: 2.5385 - val_accuracy: 0.9337 - val_loss: 2.0651 - learning_rate: 2.0000e-04
# Epoch 46/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.7946 - loss: 2.4910 - val_accuracy: 0.9366 - val_loss: 2.0241 - learning_rate: 2.0000e-04
# Epoch 47/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - accuracy: 0.8249 - loss: 2.3397 - val_accuracy: 0.9467 - val_loss: 1.9599 - learning_rate: 2.0000e-04
# Epoch 48/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - accuracy: 0.8284 - loss: 2.2706 - val_accuracy: 0.9510 - val_loss: 1.9056 - learning_rate: 2.0000e-04
# Epoch 49/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.8297 - loss: 2.2578 - val_accuracy: 0.9467 - val_loss: 1.8754 - learning_rate: 2.0000e-04
# Epoch 50/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - accuracy: 0.8441 - loss: 2.1988 - val_accuracy: 0.9510 - val_loss: 1.8388 - learning_rate: 2.0000e-04
# Epoch 51/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 132ms/step - accuracy: 0.8269 - loss: 2.1583 - val_accuracy: 0.9510 - val_loss: 1.7853 - learning_rate: 2.0000e-04
# Epoch 52/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8430 - loss: 2.0970 - val_accuracy: 0.9510 - val_loss: 1.7446 - learning_rate: 2.0000e-04
# Epoch 53/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8630 - loss: 1.9855 - val_accuracy: 0.9510 - val_loss: 1.7026 - learning_rate: 2.0000e-04
# Epoch 54/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 20s 130ms/step - accuracy: 0.8510 - loss: 1.9992 - val_accuracy: 0.9510 - val_loss: 1.6763 - learning_rate: 2.0000e-04
# Epoch 55/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.8437 - loss: 1.9825 - val_accuracy: 0.9510 - val_loss: 1.6417 - learning_rate: 2.0000e-04
# Epoch 56/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 23s 268ms/step - accuracy: 0.8659 - loss: 1.9368 - val_accuracy: 0.9553 - val_loss: 1.6153 - learning_rate: 2.0000e-04
# Epoch 57/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.8561 - loss: 1.8933 - val_accuracy: 0.9510 - val_loss: 1.5858 - learning_rate: 2.0000e-04
# Epoch 58/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8774 - loss: 1.8484 - val_accuracy: 0.9510 - val_loss: 1.5570 - learning_rate: 2.0000e-04
# Epoch 59/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.8693 - loss: 1.8613 - val_accuracy: 0.9510 - val_loss: 1.5378 - learning_rate: 2.0000e-04
# Epoch 60/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8746 - loss: 1.7933 - val_accuracy: 0.9510 - val_loss: 1.4998 - learning_rate: 2.0000e-04
# Epoch 61/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8481 - loss: 1.8192 - val_accuracy: 0.9510 - val_loss: 1.4732 - learning_rate: 2.0000e-04
# Epoch 62/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8771 - loss: 1.7373 - val_accuracy: 0.9510 - val_loss: 1.4475 - learning_rate: 2.0000e-04
# Epoch 63/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.8761 - loss: 1.6980 - val_accuracy: 0.9510 - val_loss: 1.4407 - learning_rate: 2.0000e-04
# Epoch 64/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8857 - loss: 1.6643 - val_accuracy: 0.9510 - val_loss: 1.4192 - learning_rate: 2.0000e-04
# Epoch 65/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8607 - loss: 1.7217 - val_accuracy: 0.9510 - val_loss: 1.4005 - learning_rate: 2.0000e-04
# Epoch 66/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8757 - loss: 1.6654 - val_accuracy: 0.9524 - val_loss: 1.3981 - learning_rate: 2.0000e-04
# Epoch 67/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8785 - loss: 1.6482 - val_accuracy: 0.9510 - val_loss: 1.3897 - learning_rate: 2.0000e-04
# Epoch 68/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 23s 271ms/step - accuracy: 0.9015 - loss: 1.5839 - val_accuracy: 0.9755 - val_loss: 1.3609 - learning_rate: 2.0000e-04
# Epoch 69/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 132ms/step - accuracy: 0.8966 - loss: 1.5642 - val_accuracy: 0.9539 - val_loss: 1.3493 - learning_rate: 2.0000e-04
# Epoch 70/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.8936 - loss: 1.5703 - val_accuracy: 0.9352 - val_loss: 1.3290 - learning_rate: 2.0000e-04
# Epoch 71/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.8968 - loss: 1.5423 - val_accuracy: 0.9726 - val_loss: 1.3339 - learning_rate: 2.0000e-04
# Epoch 72/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 135ms/step - accuracy: 0.9095 - loss: 1.5490 - val_accuracy: 0.9510 - val_loss: 1.3215 - learning_rate: 2.0000e-04
# Epoch 73/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 134ms/step - accuracy: 0.8903 - loss: 1.5495 - val_accuracy: 0.9510 - val_loss: 1.3170 - learning_rate: 2.0000e-04
# Epoch 74/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.8938 - loss: 1.5731 - val_accuracy: 0.9510 - val_loss: 1.3326 - learning_rate: 2.0000e-04
# Epoch 75/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 134ms/step - accuracy: 0.9034 - loss: 1.5319 - val_accuracy: 0.9510 - val_loss: 1.3030 - learning_rate: 2.0000e-04
# Epoch 76/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 138ms/step - accuracy: 0.9170 - loss: 1.4389 - val_accuracy: 0.9510 - val_loss: 1.2908 - learning_rate: 2.0000e-04
# Epoch 77/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 136ms/step - accuracy: 0.9094 - loss: 1.4713 - val_accuracy: 0.9510 - val_loss: 1.2867 - learning_rate: 2.0000e-04
# Epoch 78/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 140ms/step - accuracy: 0.8982 - loss: 1.4854 - val_accuracy: 0.9510 - val_loss: 1.2762 - learning_rate: 2.0000e-04
# Epoch 79/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 136ms/step - accuracy: 0.9062 - loss: 1.4884 - val_accuracy: 0.9510 - val_loss: 1.2757 - learning_rate: 2.0000e-04
# Epoch 80/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 20s 133ms/step - accuracy: 0.9029 - loss: 1.4428 - val_accuracy: 0.9510 - val_loss: 1.2585 - learning_rate: 2.0000e-04
# Epoch 81/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.9058 - loss: 1.4695 - val_accuracy: 0.9510 - val_loss: 1.2676 - learning_rate: 2.0000e-04
# Epoch 82/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 134ms/step - accuracy: 0.9106 - loss: 1.4573 - val_accuracy: 0.9510 - val_loss: 1.2719 - learning_rate: 2.0000e-04
# Epoch 83/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 134ms/step - accuracy: 0.9080 - loss: 1.4749 - val_accuracy: 0.9741 - val_loss: 1.2630 - learning_rate: 2.0000e-04
# Epoch 84/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 135ms/step - accuracy: 0.9111 - loss: 1.4385 - val_accuracy: 0.9755 - val_loss: 1.2523 - learning_rate: 4.0000e-05
# Epoch 85/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 134ms/step - accuracy: 0.9168 - loss: 1.4255 - val_accuracy: 0.9755 - val_loss: 1.2389 - learning_rate: 4.0000e-05
#   Test:0.9758 F1:0.9675 AUC:0.9997 Top3:1.0000 Top5:1.0000
#   ECE:0.033805 Brier:0.039465 AcuteSens:0.9167 NPV:0.9980
# =======================================================
#   FOLD 4
# =======================================================
# Epoch 1/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 36s 214ms/step - accuracy: 0.0387 - loss: 13.0303 - val_accuracy: 0.0245 - val_loss: 9.2848 - learning_rate: 0.0010
# Epoch 2/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 132ms/step - accuracy: 0.0315 - loss: 8.9554 - val_accuracy: 0.0245 - val_loss: 8.1165 - learning_rate: 0.0010
# Epoch 3/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 194ms/step - accuracy: 0.0322 - loss: 7.8736 - val_accuracy: 0.1398 - val_loss: 7.2711 - learning_rate: 0.0010
# Epoch 4/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 23s 272ms/step - accuracy: 0.0539 - loss: 7.2023 - val_accuracy: 0.1744 - val_loss: 6.9170 - learning_rate: 0.0010
# Epoch 5/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 24s 277ms/step - accuracy: 0.0956 - loss: 6.8923 - val_accuracy: 0.2421 - val_loss: 6.3484 - learning_rate: 0.0010
# Epoch 6/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 202ms/step - accuracy: 0.1546 - loss: 6.4268 - val_accuracy: 0.3588 - val_loss: 5.8266 - learning_rate: 0.0010
# Epoch 7/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 209ms/step - accuracy: 0.1947 - loss: 5.9685 - val_accuracy: 0.4092 - val_loss: 5.4664 - learning_rate: 0.0010
# Epoch 8/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 31s 328ms/step - accuracy: 0.2385 - loss: 5.8046 - val_accuracy: 0.4885 - val_loss: 4.9694 - learning_rate: 0.0010
# Epoch 9/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 23s 270ms/step - accuracy: 0.3187 - loss: 5.4026 - val_accuracy: 0.4971 - val_loss: 4.7382 - learning_rate: 0.0010
# Epoch 10/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 28s 321ms/step - accuracy: 0.3300 - loss: 5.3092 - val_accuracy: 0.5317 - val_loss: 4.8006 - learning_rate: 0.0010
# Epoch 11/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 29s 332ms/step - accuracy: 0.3702 - loss: 5.1763 - val_accuracy: 0.6254 - val_loss: 4.6080 - learning_rate: 0.0010
# Epoch 12/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 30s 347ms/step - accuracy: 0.4051 - loss: 5.0401 - val_accuracy: 0.6412 - val_loss: 4.3951 - learning_rate: 0.0010
# Epoch 13/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 213ms/step - accuracy: 0.4370 - loss: 4.8636 - val_accuracy: 0.6499 - val_loss: 4.1125 - learning_rate: 0.0010
# Epoch 14/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - accuracy: 0.4609 - loss: 4.6833 - val_accuracy: 0.7305 - val_loss: 3.9176 - learning_rate: 0.0010
# Epoch 15/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - accuracy: 0.5378 - loss: 4.4320 - val_accuracy: 0.7133 - val_loss: 3.9449 - learning_rate: 0.0010
# Epoch 16/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 19s 225ms/step - accuracy: 0.5174 - loss: 4.4902 - val_accuracy: 0.7406 - val_loss: 3.7337 - learning_rate: 0.0010
# Epoch 17/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 195ms/step - accuracy: 0.5404 - loss: 4.3422 - val_accuracy: 0.7507 - val_loss: 3.6101 - learning_rate: 0.0010
# Epoch 18/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 137ms/step - accuracy: 0.5282 - loss: 4.3687 - val_accuracy: 0.7378 - val_loss: 3.6315 - learning_rate: 0.0010
# Epoch 19/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 25s 287ms/step - accuracy: 0.5584 - loss: 4.2289 - val_accuracy: 0.7565 - val_loss: 3.4966 - learning_rate: 0.0010
# Epoch 20/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 17s 200ms/step - accuracy: 0.5723 - loss: 4.1366 - val_accuracy: 0.7723 - val_loss: 3.5308 - learning_rate: 0.0010
# Epoch 21/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 19s 217ms/step - accuracy: 0.5942 - loss: 4.2342 - val_accuracy: 0.7738 - val_loss: 3.5391 - learning_rate: 0.0010
# Epoch 22/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 135ms/step - accuracy: 0.6109 - loss: 4.1157 - val_accuracy: 0.7637 - val_loss: 3.7102 - learning_rate: 0.0010
# Epoch 23/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 140ms/step - accuracy: 0.5941 - loss: 4.2747 - val_accuracy: 0.7738 - val_loss: 3.5923 - learning_rate: 2.0000e-04
# Epoch 24/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 141ms/step - accuracy: 0.6160 - loss: 4.0610 - val_accuracy: 0.7565 - val_loss: 3.4501 - learning_rate: 2.0000e-04
# Epoch 25/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 20s 228ms/step - accuracy: 0.6260 - loss: 3.9554 - val_accuracy: 0.7983 - val_loss: 3.3293 - learning_rate: 2.0000e-04
# Epoch 26/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 140ms/step - accuracy: 0.6422 - loss: 3.8095 - val_accuracy: 0.7839 - val_loss: 3.1912 - learning_rate: 2.0000e-04
# Epoch 27/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 209ms/step - accuracy: 0.6544 - loss: 3.6531 - val_accuracy: 0.8242 - val_loss: 3.0910 - learning_rate: 2.0000e-04
# Epoch 28/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 142ms/step - accuracy: 0.6625 - loss: 3.5873 - val_accuracy: 0.8055 - val_loss: 2.9912 - learning_rate: 2.0000e-04
# Epoch 29/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 209ms/step - accuracy: 0.6733 - loss: 3.4343 - val_accuracy: 0.8285 - val_loss: 2.8744 - learning_rate: 2.0000e-04
# Epoch 30/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 187ms/step - accuracy: 0.6693 - loss: 3.3682 - val_accuracy: 0.8314 - val_loss: 2.7900 - learning_rate: 2.0000e-04
# Epoch 31/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.6891 - loss: 3.2273 - val_accuracy: 0.8516 - val_loss: 2.6900 - learning_rate: 2.0000e-04
# Epoch 32/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - accuracy: 0.6906 - loss: 3.1636 - val_accuracy: 0.8516 - val_loss: 2.6096 - learning_rate: 2.0000e-04
# Epoch 33/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 203ms/step - accuracy: 0.7141 - loss: 3.0432 - val_accuracy: 0.8991 - val_loss: 2.5597 - learning_rate: 2.0000e-04
# Epoch 34/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 136ms/step - accuracy: 0.7082 - loss: 2.9873 - val_accuracy: 0.8761 - val_loss: 2.4788 - learning_rate: 2.0000e-04
# Epoch 35/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - accuracy: 0.7197 - loss: 2.8718 - val_accuracy: 0.8761 - val_loss: 2.3896 - learning_rate: 2.0000e-04
# Epoch 36/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 134ms/step - accuracy: 0.6964 - loss: 2.8462 - val_accuracy: 0.8934 - val_loss: 2.3140 - learning_rate: 2.0000e-04
# Epoch 37/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - accuracy: 0.7263 - loss: 2.7166 - val_accuracy: 0.8963 - val_loss: 2.2348 - learning_rate: 2.0000e-04
# Epoch 38/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 16s 186ms/step - accuracy: 0.7377 - loss: 2.6413 - val_accuracy: 0.9020 - val_loss: 2.1537 - learning_rate: 2.0000e-04
# Epoch 39/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 134ms/step - accuracy: 0.7426 - loss: 2.5600 - val_accuracy: 0.8919 - val_loss: 2.0800 - learning_rate: 2.0000e-04
# Epoch 40/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - accuracy: 0.7413 - loss: 2.5336 - val_accuracy: 0.9020 - val_loss: 2.0271 - learning_rate: 2.0000e-04
# Epoch 41/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 134ms/step - accuracy: 0.7645 - loss: 2.4044 - val_accuracy: 0.9020 - val_loss: 1.9665 - learning_rate: 2.0000e-04
# Epoch 42/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 12s 134ms/step - accuracy: 0.7582 - loss: 2.3756 - val_accuracy: 0.8833 - val_loss: 1.9179 - learning_rate: 2.0000e-04
# Epoch 43/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.7676 - loss: 2.2894 - val_accuracy: 0.9020 - val_loss: 1.8483 - learning_rate: 2.0000e-04
# Epoch 44/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.7818 - loss: 2.2320 - val_accuracy: 0.9020 - val_loss: 1.7954 - learning_rate: 2.0000e-04
# Epoch 45/85
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 18s 213ms/step - accuracy: 0.7648 - loss: 2.1991 - val_accuracy: 0.9222 - val_loss: 1.7453 - learning_rate: 2.0000e-04
# Epoch 46/85
# ...
# Epoch 15/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.5101 - loss: 4.6626 - val_accuracy: 0.6983 - val_loss: 3.8911 - learning_rate: 0.0010
# Epoch 16/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 112ms/step - accuracy: 0.5515 - loss: 4.3620 - val_accuracy: 0.7241 - val_loss: 3.7426 - learning_rate: 0.0010
# Epoch 17/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.5333 - loss: 4.4167 - val_accuracy: 0.7471 - val_loss: 3.6829 - learning_rate: 0.0010
# Epoch 18/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 110ms/step - accuracy: 0.5436 - loss: 4.3953 - val_accuracy: 0.7644 - val_loss: 3.7334 - learning_rate: 0.0010
# Epoch 19/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.5627 - loss: 4.3367 - val_accuracy: 0.7730 - val_loss: 3.6707 - learning_rate: 0.0010
# Epoch 20/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 111ms/step - accuracy: 0.5697 - loss: 4.4245 - val_accuracy: 0.8017 - val_loss: 3.8008 - learning_rate: 0.0010
# Epoch 21/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 110ms/step - accuracy: 0.6108 - loss: 4.5061 - val_accuracy: 0.7759 - val_loss: 3.8274 - learning_rate: 0.0010
# Epoch 22/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.6102 - loss: 4.4875 - val_accuracy: 0.7960 - val_loss: 3.8670 - learning_rate: 0.0010
# Epoch 23/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - accuracy: 0.6220 - loss: 4.4718 - val_accuracy: 0.7931 - val_loss: 3.7710 - learning_rate: 2.0000e-04
# Epoch 24/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.6432 - loss: 4.3186 - val_accuracy: 0.7989 - val_loss: 3.6376 - learning_rate: 2.0000e-04
# Epoch 25/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.6682 - loss: 4.0837 - val_accuracy: 0.7989 - val_loss: 3.5114 - learning_rate: 2.0000e-04
# Epoch 26/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.6642 - loss: 3.9388 - val_accuracy: 0.7989 - val_loss: 3.3762 - learning_rate: 2.0000e-04
# Epoch 27/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.6717 - loss: 3.8398 - val_accuracy: 0.7989 - val_loss: 3.2623 - learning_rate: 2.0000e-04
# Epoch 28/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.6973 - loss: 3.6574 - val_accuracy: 0.7989 - val_loss: 3.1607 - learning_rate: 2.0000e-04
# Epoch 29/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - accuracy: 0.6952 - loss: 3.5397 - val_accuracy: 0.7989 - val_loss: 3.0571 - learning_rate: 2.0000e-04
# Epoch 30/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.7000 - loss: 3.4591 - val_accuracy: 0.7989 - val_loss: 2.9682 - learning_rate: 2.0000e-04
# Epoch 31/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.7145 - loss: 3.3239 - val_accuracy: 0.8247 - val_loss: 2.8672 - learning_rate: 2.0000e-04
# Epoch 32/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.6995 - loss: 3.2601 - val_accuracy: 0.8075 - val_loss: 2.7818 - learning_rate: 2.0000e-04
# Epoch 33/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.7243 - loss: 3.1088 - val_accuracy: 0.8247 - val_loss: 2.6942 - learning_rate: 2.0000e-04
# Epoch 34/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.7164 - loss: 3.0706 - val_accuracy: 0.8247 - val_loss: 2.6097 - learning_rate: 2.0000e-04
# Epoch 35/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.7352 - loss: 2.9220 - val_accuracy: 0.8534 - val_loss: 2.5012 - learning_rate: 2.0000e-04
# Epoch 36/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 111ms/step - accuracy: 0.7268 - loss: 2.8416 - val_accuracy: 0.8534 - val_loss: 2.4083 - learning_rate: 2.0000e-04
# Epoch 37/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 112ms/step - accuracy: 0.7324 - loss: 2.8028 - val_accuracy: 0.8621 - val_loss: 2.3238 - learning_rate: 2.0000e-04
# Epoch 38/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 113ms/step - accuracy: 0.7401 - loss: 2.6906 - val_accuracy: 0.8621 - val_loss: 2.2380 - learning_rate: 2.0000e-04
# Epoch 39/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.7544 - loss: 2.6165 - val_accuracy: 0.8621 - val_loss: 2.1714 - learning_rate: 2.0000e-04
# Epoch 40/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.7630 - loss: 2.4896 - val_accuracy: 0.8621 - val_loss: 2.0980 - learning_rate: 2.0000e-04
# Epoch 41/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 115ms/step - accuracy: 0.7599 - loss: 2.4373 - val_accuracy: 0.8621 - val_loss: 2.0330 - learning_rate: 2.0000e-04
# Epoch 42/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.7803 - loss: 2.3697 - val_accuracy: 0.8621 - val_loss: 1.9738 - learning_rate: 2.0000e-04
# Epoch 43/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.7712 - loss: 2.3093 - val_accuracy: 0.8793 - val_loss: 1.9179 - learning_rate: 2.0000e-04
# Epoch 44/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - accuracy: 0.7807 - loss: 2.2368 - val_accuracy: 0.8879 - val_loss: 1.8690 - learning_rate: 2.0000e-04
# Epoch 45/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.7659 - loss: 2.2146 - val_accuracy: 0.8879 - val_loss: 1.8282 - learning_rate: 2.0000e-04
# Epoch 46/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.7788 - loss: 2.1361 - val_accuracy: 0.8678 - val_loss: 1.7902 - learning_rate: 2.0000e-04
# Epoch 47/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.7920 - loss: 2.0834 - val_accuracy: 0.9138 - val_loss: 1.7384 - learning_rate: 2.0000e-04
# Epoch 48/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.7950 - loss: 2.0466 - val_accuracy: 0.9109 - val_loss: 1.6948 - learning_rate: 2.0000e-04
# Epoch 49/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.7909 - loss: 1.9922 - val_accuracy: 0.9310 - val_loss: 1.6521 - learning_rate: 2.0000e-04
# Epoch 50/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.7982 - loss: 1.9443 - val_accuracy: 0.9339 - val_loss: 1.6231 - learning_rate: 2.0000e-04
# Epoch 51/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 113ms/step - accuracy: 0.8105 - loss: 1.8846 - val_accuracy: 0.9339 - val_loss: 1.5799 - learning_rate: 2.0000e-04
# Epoch 52/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.8107 - loss: 1.8817 - val_accuracy: 0.9339 - val_loss: 1.5464 - learning_rate: 2.0000e-04
# Epoch 53/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - accuracy: 0.8110 - loss: 1.8550 - val_accuracy: 0.9339 - val_loss: 1.4944 - learning_rate: 2.0000e-04
# Epoch 54/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 115ms/step - accuracy: 0.8381 - loss: 1.7551 - val_accuracy: 0.9483 - val_loss: 1.4656 - learning_rate: 2.0000e-04
# Epoch 55/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 115ms/step - accuracy: 0.8423 - loss: 1.7219 - val_accuracy: 0.9339 - val_loss: 1.4243 - learning_rate: 2.0000e-04
# Epoch 56/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 112ms/step - accuracy: 0.8325 - loss: 1.7085 - val_accuracy: 0.9511 - val_loss: 1.3938 - learning_rate: 2.0000e-04
# Epoch 57/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 112ms/step - accuracy: 0.8337 - loss: 1.6882 - val_accuracy: 0.9483 - val_loss: 1.3912 - learning_rate: 2.0000e-04
# Epoch 58/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 112ms/step - accuracy: 0.8407 - loss: 1.6672 - val_accuracy: 0.9483 - val_loss: 1.3572 - learning_rate: 2.0000e-04
# Epoch 59/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 111ms/step - accuracy: 0.8344 - loss: 1.6765 - val_accuracy: 0.9540 - val_loss: 1.3587 - learning_rate: 2.0000e-04
# Epoch 60/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.8623 - loss: 1.6109 - val_accuracy: 0.9511 - val_loss: 1.3380 - learning_rate: 2.0000e-04
# Epoch 61/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.8455 - loss: 1.6389 - val_accuracy: 0.9511 - val_loss: 1.3192 - learning_rate: 2.0000e-04
# Epoch 62/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.8759 - loss: 1.5328 - val_accuracy: 0.9713 - val_loss: 1.3007 - learning_rate: 2.0000e-04
# Epoch 63/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 113ms/step - accuracy: 0.8619 - loss: 1.5803 - val_accuracy: 0.9741 - val_loss: 1.2654 - learning_rate: 2.0000e-04
# Epoch 64/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - accuracy: 0.8796 - loss: 1.5125 - val_accuracy: 0.9483 - val_loss: 1.2339 - learning_rate: 2.0000e-04
# Epoch 65/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 115ms/step - accuracy: 0.8749 - loss: 1.5082 - val_accuracy: 0.9454 - val_loss: 1.2262 - learning_rate: 2.0000e-04
# Epoch 66/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 113ms/step - accuracy: 0.8855 - loss: 1.4788 - val_accuracy: 0.9454 - val_loss: 1.2056 - learning_rate: 2.0000e-04
# Epoch 67/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 114ms/step - accuracy: 0.8708 - loss: 1.4903 - val_accuracy: 0.9483 - val_loss: 1.2219 - learning_rate: 2.0000e-04
# Epoch 68/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - accuracy: 0.8943 - loss: 1.4540 - val_accuracy: 0.9626 - val_loss: 1.2056 - learning_rate: 2.0000e-04
# Epoch 69/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 115ms/step - accuracy: 0.9089 - loss: 1.4352 - val_accuracy: 0.9741 - val_loss: 1.2024 - learning_rate: 2.0000e-04
# Epoch 70/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 115ms/step - accuracy: 0.9093 - loss: 1.4442 - val_accuracy: 0.9741 - val_loss: 1.2001 - learning_rate: 2.0000e-04
# Epoch 71/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.9083 - loss: 1.4127 - val_accuracy: 0.9741 - val_loss: 1.1832 - learning_rate: 2.0000e-04
# Epoch 72/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 115ms/step - accuracy: 0.9074 - loss: 1.4395 - val_accuracy: 0.9741 - val_loss: 1.1806 - learning_rate: 2.0000e-04
# Epoch 73/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 116ms/step - accuracy: 0.9147 - loss: 1.4119 - val_accuracy: 0.9741 - val_loss: 1.1746 - learning_rate: 2.0000e-04
# Epoch 74/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 12s 118ms/step - accuracy: 0.9174 - loss: 1.3606 - val_accuracy: 0.9741 - val_loss: 1.1488 - learning_rate: 2.0000e-04
# Epoch 75/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.9257 - loss: 1.3382 - val_accuracy: 0.9741 - val_loss: 1.1331 - learning_rate: 2.0000e-04
# Epoch 76/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 111ms/step - accuracy: 0.9229 - loss: 1.3461 - val_accuracy: 0.9770 - val_loss: 1.1516 - learning_rate: 2.0000e-04
# Epoch 77/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.9293 - loss: 1.3581 - val_accuracy: 1.0000 - val_loss: 1.1647 - learning_rate: 2.0000e-04
# Epoch 78/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 116ms/step - accuracy: 0.9249 - loss: 1.3361 - val_accuracy: 0.9741 - val_loss: 1.1144 - learning_rate: 2.0000e-04
# Epoch 79/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.9220 - loss: 1.3295 - val_accuracy: 0.9943 - val_loss: 1.1562 - learning_rate: 2.0000e-04
# Epoch 80/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 112ms/step - accuracy: 0.9297 - loss: 1.2978 - val_accuracy: 1.0000 - val_loss: 1.1395 - learning_rate: 2.0000e-04
# Epoch 81/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - accuracy: 0.9417 - loss: 1.3097 - val_accuracy: 1.0000 - val_loss: 1.0917 - learning_rate: 2.0000e-04
# Epoch 82/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 21s 116ms/step - accuracy: 0.9377 - loss: 1.2682 - val_accuracy: 1.0000 - val_loss: 1.0855 - learning_rate: 2.0000e-04
# Epoch 83/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 116ms/step - accuracy: 0.9410 - loss: 1.2800 - val_accuracy: 1.0000 - val_loss: 1.0802 - learning_rate: 2.0000e-04
# Epoch 84/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.9333 - loss: 1.2915 - val_accuracy: 1.0000 - val_loss: 1.0959 - learning_rate: 2.0000e-04
# Epoch 85/85
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.9593 - loss: 1.2397 - val_accuracy: 1.0000 - val_loss: 1.0847 - learning_rate: 2.0000e-04
#   Final: Acc=1.0000 Loss=1.0806
#
# ======================================================================
#   Q3: SYMPTOM MODEL AGGREGATE
# ======================================================================
#   Train Loss               : 1.2935 ± 0.0970
#   Train Acc                : 0.9331 ± 0.0146
#   Val Loss                 : 1.1030 ± 0.0966
#   Val Acc                  : 0.9902 ± 0.0134
#   Test Loss                : 1.0974 ± 0.0947
#   Test Acc                 : 0.9952 ± 0.0108
#   Macro F1                 : 0.9935 ± 0.0145
#   Roc Auc                  : 0.9999 ± 0.0001
#   Top3                     : 1.0000 ± 0.0000
#   Top5                     : 1.0000 ± 0.0000
#   Ece                      : 0.027358 ± 0.013046
#   Brier                    : 0.022409 ± 0.015118
#   Sens Acute               : 0.9833 ± 0.0373
#   Npv Acute                : 0.9996 ± 0.0009
#
#   CLASSIFICATION REPORT:
#                                precision    recall  f1-score   support
#
#                          AIDS       1.00      1.00      1.00       180
#                          Acne       1.00      1.00      1.00       180
#           Alcoholic Hepatitis       1.00      1.00      1.00       180
#                       Allergy       1.00      1.00      1.00       185
#                     Arthritis       1.00      1.00      1.00       180
#              Bronchial Asthma       1.00      1.00      1.00       180
#          Cervical Spondylosis       1.00      1.00      1.00       180
#                    Chickenpox       1.00      1.00      1.00       185
#           Chronic Cholestasis       1.00      1.00      1.00       180
#                   Common Cold       1.00      1.00      1.00       180
#                        Dengue       1.00      1.00      1.00       185
#                     Diabetes        1.00      1.00      1.00       180
# Dimorphic Hemmorhoids (piles)       1.00      1.00      1.00       180
#                 Drug Reaction       1.00      1.00      1.00       180
#              Fungal Infection       1.00      1.00      1.00       185
#                          GERD       0.83      1.00      0.91       180
#               Gastroenteritis       1.00      1.00      1.00       180
#                  Heart Attack       1.00      0.80      0.89       180
#                   Hepatitis A       1.00      1.00      1.00       185
#                   Hepatitis B       1.00      1.00      1.00       180
#                   Hepatitis C       1.00      1.00      1.00       185
#                   Hepatitis D       1.00      1.00      1.00       180
#                   Hepatitis E       1.00      1.00      1.00       185
#                 Hypertension        1.00      1.00      1.00       185
#               Hyperthyroidism       1.00      1.00      1.00       180
#                  Hypoglycemia       1.00      1.00      1.00       180
#                Hypothyroidism       1.00      1.00      1.00       180
#                      Impetigo       1.00      1.00      1.00       180
#                      Jaundice       1.00      1.00      1.00       185
#                       Malaria       1.00      1.00      1.00       180
#                      Migraine       1.00      1.00      1.00       180
#                Osteoarthritis       1.00      1.00      1.00       180
#  Paralysis (brain hemorrhage)       1.00      1.00      1.00       180
#          Peptic Ulcer Disease       1.00      1.00      1.00       185
#                     Pneumonia       1.00      1.00      1.00       180
#                     Psoriasis       1.00      1.00      1.00       180
#                  Tuberculosis       1.00      1.00      1.00       185
#                       Typhoid       1.00      1.00      1.00       185
#       Urinary Tract Infection       1.00      1.00      1.00       185
#                Varicose Veins       1.00      1.00      1.00       180
#                       Vertigo       1.00      1.00      1.00       180
#
#                      accuracy                           1.00      7445
#                     macro avg       1.00      1.00      1.00      7445
#                  weighted avg       1.00      1.00      1.00      7445
# ======================================================================
#   Q4: CALIBRATION
# ======================================================================
#   Threshold Sweep:
#   θ=0.800 → Cov:0.9494 Acc:1.0000 AcFN:0.0000
#   θ=0.900 → Cov:0.9440 Acc:1.0000 AcFN:0.0000
#   θ=0.950 → Cov:0.9369 Acc:1.0000 AcFN:0.0000
#   θ=0.975 → Cov:0.9336 Acc:1.0000 AcFN:0.0000
#   Cost/sample: 0.0532 ± 0.1189
#     Acute-Critical: Sens=0.9333 (540 samples)
#     Acute-Moderate: Sens=1.0000 (1460 samples)
#     Chronic: Sens=1.0000 (1805 samples)
#
# ✅ DONE! Models: /content/saved_models/ | Figures: /content/figures/ | Results: /content/results/
